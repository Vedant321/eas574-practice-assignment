# %% [markdown]
# # EAS 574 - Assignment Template
#
# **Student Name:** [Your Name Here]
#
# **UB Person Number:** [Your Person Number]
#
# ---
#
# ## Instructions
#
# 1. Complete all cells marked with `# YOUR CODE HERE`
# 2. Do not modify the test cells
# 3. Run all cells before submitting
# 4. Commit and push your changes to GitHub

# %%
# Standard imports - do not modify
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ## Part 1: Load and Explore Data
#
# We'll work with a simple synthetic dataset.

# %%
# Generate synthetic data
n = 100
X = np.random.uniform(0, 10, n)
y = 2.5 * X + 5 + np.random.normal(0, 2, n)  # y = 2.5x + 5 + noise

# Create DataFrame
df = pd.DataFrame({'X': X, 'y': y})
df.head()
# Out:
#           X          y
# 0  3.745401  14.537597
# 1  9.507143  28.169843
# 2  7.319939  23.483370
# 3  5.986585  15.991324
# 4  1.560186   8.461122

# %% [markdown]
# ### Task 1.1: Basic Statistics (5 points)
#
# Calculate the mean of `X` and the mean of `y`. Store them in variables `mean_x` and `mean_y`.

# %%
# YOUR CODE HERE
mean_x = df["X"].mean()
mean_y = df["y"].mean()

print(f"Mean of X: {mean_x}")
print(f"Mean of y: {mean_y}")
# Out:
# Mean of X: 4.701807433782093
# Mean of y: 16.752357864120516

# %% [markdown]
# ### Task 1.2: Scatter Plot (5 points)
#
# Create a scatter plot of X vs y. Label your axes.

# %%
# YOUR CODE HERE
plt.scatter(X, y)

# %% [markdown]
# ## Part 2: Simple Linear Regression
#
# ### Task 2.1: Calculate Slope and Intercept (10 points)
#
# Using the formulas from class, calculate the slope (`beta_1`) and intercept (`beta_0`) for simple linear regression.
#
# Recall:
# - $\hat{\beta}_1 = \frac{\sum_{i=1}^{n}(x_i - \bar{x})(y_i - \bar{y})}{\sum_{i=1}^{n}(x_i - \bar{x})^2}$
# - $\hat{\beta}_0 = \bar{y} - \hat{\beta}_1 \bar{x}$

# %%
# YOUR CODE HERE
x_bar = np.mean(X)
y_bar = np.mean(y)

beta_1 = np.sum((X - x_bar) * (y - y_bar)) / np.sum((X - x_bar) ** 2)

beta_0 = y_bar - beta_1 * x_bar

print(f"Slope (beta_1): {beta_1}")
print(f"Intercept (beta_0): {beta_0}")
# Out:
# Slope (beta_1): 2.408045354575394
# Intercept (beta_0): 5.430192315093491

# %% [markdown]
# ### Task 2.2: Make Predictions (5 points)
#
# Using your calculated `beta_0` and `beta_1`, create predictions `y_pred` for all values in `X`.

# %%
# YOUR CODE HERE
y_pred = beta_0 + beta_1 * X


print(f"First 5 predictions: {y_pred}")
# Out:
# First 5 predictions: [14.44928825 28.32382401 23.05693843 19.84616013  9.18719194  9.18661112
#   6.82887204 26.28810676 19.90531443 22.48090113  5.92587627 28.78606145
#  25.47578866 10.54341441  9.80861999  9.84665609 12.75648351 18.06656519
#  15.83162427 12.4431221  20.16388752  8.78926775 12.46516795 14.25235166
#  16.41256438 24.33758558 10.23842755 17.81319082 19.69580382  6.54873932
#  20.0601479   9.53649055  6.99666418 28.27978642 28.68304963 24.8967671
#  12.76543003  7.78218112 21.90683392 16.02926399  8.36892836 17.3542769
#   6.2582835  27.32704002 11.66173164 21.38402941 12.9363364  17.95366614
#  18.5952238   9.88157144 28.7782299  24.09574226 28.05375293 26.97804076
#  19.82789498 27.62934201  7.5611319  10.14954853  6.51928594 13.26429423
#  14.78971773 11.96440007 25.38656741 14.02097423 12.19522273 18.49856014
#   8.82371157 24.74745944  7.22540563 29.19487735 24.02619661 10.21535605
#   5.5631674  25.06687336 22.45163775 22.98501556 24.00273207  7.21322111
#  14.06220964  8.22037182 26.21411427 20.4394939  13.39836683  6.96070622
#  12.91878767 13.2607542  22.99944    20.78286539 26.79467755 16.80134188
#   8.310076   22.60545028 23.75024134 18.9460018  23.99543168 17.32101423
#  18.01783593 15.72557395  6.04229642  8.02826681]

# %% [markdown]
# ### Task 2.3: Plot Regression Line (5 points)
#
# Create a scatter plot of the data with your regression line overlaid.

# %%
x_line = np.linspace(X.min(), X.max(), 100)
y_line = beta_0 + beta_1 * x_line

plt.figure(figsize=(6, 4))
plt.scatter(X, y, color="blue", label="Observed Data")
plt.plot(x_line, y_line, color="red", label="Regression Line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Simple Linear Regression")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Part 3: Model Evaluation
#
# ### Task 3.1: Calculate MSE (5 points)
#
# Calculate the Mean Squared Error of your predictions.
#
# $MSE = \frac{1}{n}\sum_{i=1}^{n}(y_i - \hat{y}_i)^2$

# %%
# YOUR CODE HERE
mse = np.mean((y - y_pred) ** 2)

print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 3.226338255868214

# %% [markdown]
# ### Task 3.2: Calculate R-squared (5 points)
#
# Calculate the R-squared value.
#
# $R^2 = 1 - \frac{SS_{res}}{SS_{tot}} = 1 - \frac{\sum(y_i - \hat{y}_i)^2}{\sum(y_i - \bar{y})^2}$

# %%
# YOUR CODE HERE
ss_res = np.sum((y - y_pred) ** 2)     
ss_tot = np.sum((y - y_bar) ** 2)

r_squared = 1 - (ss_res / ss_tot)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.9402877892004072

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# Before submitting, make sure:
# - [ ] All cells run without errors
# - [ ] All `# YOUR CODE HERE` sections are completed
# - [ ] Your name and person number are filled in at the top
# - [ ] You have committed and pushed to GitHub
